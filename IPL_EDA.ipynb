# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ipl_df = pd.read_csv('D:\PYTHON\Data Analyst\py_data_viz\IPL Matches.csv')

# %% [markdown]
# ## Data cleaning

# %%
ipl_df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl_df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
ipl_df.drop(columns=['method','umpire1','umpire2','neutral_venue'],inplace = True)

# %%
#info() gives datatypes of columns
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   team1            816 non-null    object
#  6   team2            816 non-null    object
#  7   toss_winner      816 non-null    object
#  8   toss_decision    816 non-null    object
#  9   winner           812 non-null    object
#  10  result           812 non-null    object
#  11  result_margin    799 non-null    float64
#  12  eliminator       812 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 83.0+ KB

# %%
ipl_df.shape
# Out:
# (816, 13)

# %%
#describes tells us the overview of dataset 
ipl_df.describe
# Out:
# <bound method NDFrame.describe of           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# ...

# %%
ipl_df.isnull().sum()
# Out:
# id                  0
# city               13
# date                0
# player_of_match     4
# venue               0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner              4
# result              4
# result_margin      17
# eliminator          4
# dtype: int64

# %%
ipl_df.city.unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Rajkot', 'Kanpur', 'Bengaluru', 'Dubai',
#        'Sharjah'], dtype=object)

# %%
ipl_df.team2.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
#Replacing same teams with different names
ipl_df.team1.replace({'Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants','Deccan Chargers':'Sunrisers Hyderabad','Delhi Daredevils':'Delhi Capitals'},inplace = True)
ipl_df.team2.replace({'Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants','Deccan Chargers':'Sunrisers Hyderabad','Delhi Daredevils':'Delhi Capitals'},inplace = True)
ipl_df.winner.replace({'Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants','Deccan Chargers':'Sunrisers Hyderabad','Delhi Daredevils':'Delhi Capitals'},inplace = True)
ipl_df.toss_winner.replace({'Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants','Deccan Chargers':'Sunrisers Hyderabad','Delhi Daredevils':'Delhi Capitals'},inplace = True)

# %%
ipl_df.team2.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Kings XI Punjab', 'Delhi Capitals', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants', 'Gujarat Lions'],
#       dtype=object)

# %%
#Replacing similar cities with different spellings and nan with mumbai
ipl_df.city.replace({'Bangalore':'Bengaluru'},inplace = True)

# %%
ipl_df.city.unique()
# Out:
# array(['Bengaluru', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Rajkot', 'Kanpur', 'Dubai', 'Sharjah'],
#       dtype=object)

# %%
# we can use .isnull() to set Null values to True and then use .sum() to calculate all the null values
ipl_df.isnull().sum().sum()
# Out:
# 16

# %%
null_df = ipl_df[ipl_df.isna().any(axis=1)]

# %%
null_df
# Out:
#           id       city        date player_of_match  \
# 66    392190  Cape Town  2009-04-23       YK Pathan
# 130   419121    Chennai  2010-03-21        J Theron
# 241   501265      Delhi  2011-05-21             NaN
# 328   598004  Hyderabad  2013-04-07       GH Vihari
# 341   598017  Bengaluru  2013-04-16         V Kohli
# 399   729281        NaN  2014-04-17       YS Chahal
# 402   729287        NaN  2014-04-19        PA Patel
# 403   729289        NaN  2014-04-19       JP Duminy
# 404   729291        NaN  2014-04-20      GJ Maxwell
# 406   729295        NaN  2014-04-22      GJ Maxwell
# 407   729297        NaN  2014-04-23       RA Jadeja
# 408   729299        NaN  2014-04-24         CA Lynn
# 409   729301        NaN  2014-04-25        AJ Finch
# 410   729303        NaN  2014-04-25       MM Sharma
# 413   729309        NaN  2014-04-27         M Vijay
# 414   729311        NaN  2014-04-27        DR Smith
# 415   729313        NaN  2014-04-28  Sandeep Sharma
# ...

# %% [markdown]
# we will replace 'nan' in city with Mumbai

# %%
ipl_df.loc[[399,402,403,404,406,408,407,409,410,413,414,415,415,417],'city']='Mumbai'

# %%
ipl_df.loc[399:420]
# Out:
#          id       city        date player_of_match  \
# 399  729281     Mumbai  2014-04-17       YS Chahal
# 400  729283  Abu Dhabi  2014-04-18      GJ Maxwell
# 401  729285  Abu Dhabi  2014-04-18       AM Rahane
# 402  729287     Mumbai  2014-04-19        PA Patel
# 403  729289     Mumbai  2014-04-19       JP Duminy
# 404  729291     Mumbai  2014-04-20      GJ Maxwell
# 405  729293  Abu Dhabi  2014-04-21        SK Raina
# 406  729295     Mumbai  2014-04-22      GJ Maxwell
# 407  729297     Mumbai  2014-04-23       RA Jadeja
# 408  729299     Mumbai  2014-04-24         CA Lynn
# 409  729301     Mumbai  2014-04-25        AJ Finch
# 410  729303     Mumbai  2014-04-25       MM Sharma
# 411  729305  Abu Dhabi  2014-04-26        PV Tambe
# 412  729307  Abu Dhabi  2014-04-26  Sandeep Sharma
# 413  729309     Mumbai  2014-04-27         M Vijay
# 414  729311     Mumbai  2014-04-27        DR Smith
# 415  729313     Mumbai  2014-04-28  Sandeep Sharma
# ...

# %%
#replacing nan values with 0
ipl_df['result_margin']=ipl_df['result_margin'].fillna(0)

# %%
ipl_df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bengaluru  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla               Delhi Capitals
# ...

# %%
#checking if we have any NaN values in City 
ipl_df.city.isnull().any()
# Out:
# False

# %%
# Lets Check if any any other COlumns Have NaN values
ipl_df.isna().any()[lambda x: x]
# Out:
# player_of_match    True
# winner             True
# result             True
# eliminator         True
# dtype: bool

# %% [markdown]
# # Analysis

# %%
#count no. of matches
ipl_df.id.count()
# Out:
# 816

# %%
tie_matches = ipl_df[ipl_df.result == 'tie'].count()
second_bat_win = ipl_df[ipl_df.result == 'wickets'].count()
second_ball_win = ipl_df[ipl_df.result == 'runs'].count()

second_bat_win.result
# Out:
# 435

# %%
 tie_matches.result
# Out:
# 13

# %%
 second_ball_win.result
# Out:
# 364

# %% [markdown]
#  Total matches won by each team

# %%
ipl_df.winner.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Capitals',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Sunrisers Hyderabad', 'Mumbai Indians',
#        'Rising Pune Supergiants', 'Kochi Tuskers Kerala', nan,
#        'Gujarat Lions'], dtype=object)

# %%
winner_df = ipl_df.groupby('winner')[['id']].count()
winner_df = winner_df.sort_values('id',ascending = False).reset_index()
winner_df.rename(columns={ 'id':'won' ,'winner':'Teams' },inplace = True)
# winner_df = ipl_df.groupby('winner')[['id']].count()
# winner_df = winner_df.sort_values('id', ascending=False).reset_index()

# winner_df.rename(columns = {'id':'wins','winner':'Teams'},inplace=True)
# winner_df

# %%
winner_df
# Out:
#                           Teams  won
# 0                Mumbai Indians  120
# 1           Chennai Super Kings  106
# 2         Kolkata Knight Riders   99
# 3           Sunrisers Hyderabad   95
# 4   Royal Challengers Bangalore   91
# 5               Kings XI Punjab   88
# 6                Delhi Capitals   86
# 7              Rajasthan Royals   81
# 8       Rising Pune Supergiants   27
# 9                 Gujarat Lions   13
# 10         Kochi Tuskers Kerala    6

# %%
plt.figure(figsize = (50,30))
plt.title('Matches won by teams',fontsize = 40,fontweight = 'bold')
plt.xlabel('Teams',fontsize = 40,fontweight = 'bold')
plt.ylabel('won',fontsize = 40,fontweight = 'bold')
plt.tick_params(labelsize=40)
plt.xticks(rotation=70)
plt.bar(winner_df.Teams,winner_df.won,color = ['blue','yellow','indigo','darkorange','red','crimson','royalblue','cornflowerblue','dimgrey','gold','green']);

# %% [markdown]
# Total Matches played in each seasons

# %%
ipl_df['date'] = pd.to_datetime(ipl_df['date'], errors='coerce')
ipl_df['season']= ipl_df['date'].dt.year

# %%
ipl_df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bengaluru 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla               Delhi Capitals
# ...

# %%
total_matches_df = ipl_df.groupby('season')[['id']].count()
total_matches_df = total_matches_df.sort_values('id',ascending = False).reset_index()
total_matches_df.rename(columns={ 'id':'matches' ,'season':'years' },inplace = True)
total_matches_df
# Out:
#     years  matches
# 0    2013       76
# 1    2012       74
# 2    2011       73
# 3    2010       60
# 4    2014       60
# 5    2016       60
# 6    2018       60
# 7    2019       60
# 8    2020       60
# 9    2015       59
# 10   2017       59
# 11   2008       58
# 12   2009       57

# %%
plt.figure(figsize=(20,10))

plt.title('Total matches in each season',fontsize = 20,fontweight = 'bold')
plt.xlabel('IPL Seasons',fontsize = 20,fontweight = 'bold')
plt.ylabel('Matches',fontsize = 20,fontweight = 'bold');
plt.tick_params(labelsize=20)
plt.bar(total_matches_df.years,total_matches_df.matches,color=['teal','firebrick','olivedrab'] ,edgecolor='black');

# %% [markdown]
# Who has the most 'player of the match'  trophy?
#
# Which venue has hosted most matches till 2020 ?
#
# What was the best decission bat or field after winning toss?
#
# Which decission has proved right maximun times?
#
# What is the Maximum result of wining i.e either bat or field or the match is tie?
#
# Which team has won ipl trophy most of times?
#
# How many matches did each season had?

# %% [markdown]
# # ***Who has the most 'player of the match' trophy?***

# %%
#grouping all the players who got trophy n sorting
playerofmatches_df = ipl_df.groupby('player_of_match')[['id']].count()
playerofmatches_df = playerofmatches_df.sort_values('id',ascending = True).reset_index()
playerofmatches_df.rename(columns={'id':'total_trophies','player_of_match':'player_name'} , inplace =True)

# %%
top_player = playerofmatches_df.tail(15)
top_player
# Out:
#         player_name  total_trophies
# 218        A Mishra              11
# 219        V Sehwag              11
# 220      KA Pollard              11
# 221      MEK Hussey              12
# 222       AM Rahane              12
# 223         V Kohli              13
# 224       G Gambhir              13
# 225        SK Raina              14
# 226       SR Watson              16
# 227       YK Pathan              16
# 228       DA Warner              17
# 229        MS Dhoni              17
# 230       RG Sharma              18
# 231        CH Gayle              22
# 232  AB de Villiers              23

# %%
plt.figure(figsize=(12,8))
plt.title('Top 15 palyers awarded Player Of Match trophy',fontsize = 20,fontweight = 'bold')
plt.xlabel('Highest Number of Trophies',fontsize = 20,fontweight = 'bold')
plt.ylabel('Players name',fontsize = 20,fontweight = 'bold')
plt.tick_params(labelsize = 12)
plt.barh(top_player.player_name,top_player.total_trophies,color = 'firebrick');

# %% [markdown]
# # *Which venue has hosted most matches till 2020 ?*

# %%
#total number of venues where ipl has hosted matches
len(ipl_df.venue.unique())
# Out:
# 36

# %% [markdown]
# There are 36 different venues in total.

# %%
venue_df = ipl_df.groupby('venue')[['id']].count()
venue_df = venue_df.sort_values('id',ascending = False).reset_index()
venue_df.rename(columns = {'id':'total_matches'},inplace = True)

# %%
venue_df
# Out:
#                                                 venue  total_matches
# 0                                        Eden Gardens             77
# 1                                    Feroz Shah Kotla             74
# 2                                    Wankhede Stadium             73
# 3                               M Chinnaswamy Stadium             65
# 4           Rajiv Gandhi International Stadium, Uppal             64
# 5                     MA Chidambaram Stadium, Chepauk             57
# 6                              Sawai Mansingh Stadium             47
# 7          Punjab Cricket Association Stadium, Mohali             35
# 8                 Dubai International Cricket Stadium             33
# 9                                Sheikh Zayed Stadium             29
# 10  Punjab Cricket Association IS Bindra Stadium, ...             21
# 11            Maharashtra Cricket Association Stadium             21
# 12                            Sharjah Cricket Stadium             18
# ...

# %%
plt.figure(figsize=(30,12))
a =sns.barplot(x=venue_df.venue , y=venue_df.total_matches);

a.axes.set_title("Different venues where match held",fontsize=30,fontweight='bold')
a.set_xlabel('Venue',fontsize = 30,fontweight='bold')
a.set_ylabel('Total Matches',fontsize = 20,fontweight='bold');
plt.xticks(rotation = 80)
plt.tick_params(labelsize=15);

# %% [markdown]
# # *What decision was taken most of the time after winning the toss ?*

# %%
ipl_df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bengaluru 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla               Delhi Capitals
# ...

# %%
decision = ipl_df.groupby('toss_decision')[['id']].count().sort_values('id', ascending = 'True').reset_index()
decision.rename(columns = {'id':'Total','toss_decision':'Decision'} , inplace = True)
decision
# Out:
#   Decision  Total
# 0      bat    320
# 1    field    496

# %%
plt.figure(figsize=(8,8))
plt.title('Toss Decision',fontsize=30,fontweight='bold')
plt.xlabel('Decision',fontsize=20,fontweight='bold')
plt.ylabel('Total',fontsize=20,fontweight='bold')
plt.tick_params(labelsize=20)
sns.barplot(x = decision.Decision,y = decision.Total, data = decision, hue = 'Decision');

# %% [markdown]
# # Which decission has proved right maximun times?

# %%
balling = ipl_df.loc[(ipl_df['toss_winner'] == ipl_df['winner']) & (ipl_df['toss_decision'] == 'field'),['id','winner','toss_decision']]

# %%
a = balling.winner.count()
a
# Out:
# 273

# %%
bat = ipl_df.loc[(ipl_df['toss_winner'] == ipl_df['winner']) & (ipl_df['toss_decision'] == 'bat'),['id','winner','toss_decision']]

# %%
b = bat.winner.count()
b
# Out:
# 145

# %%
result = pd.concat([bat,balling])
result = result.groupby('toss_decision')[['id']].count().reset_index()
result.rename(columns ={'toss_decision':'Decission','id':'Total'},inplace = True)

# %%
result
# Out:
#   Decission  Total
# 0       bat    145
# 1     field    273

# %%
plt.figure(figsize=(8,8))
plt.grid()
plt.title('Toss Decision Proved Right',fontsize=25,fontweight='bold')
plt.xlabel('Decision',fontsize=20,fontweight='bold')
plt.ylabel('Total',fontsize=20,fontweight='bold')
plt.tick_params(labelsize=20)
plt.bar(decision.Decision,decision.Total , color = ['coral'])
plt.bar(result.Decission , result.Total, color = ['royalblue']) 
plt.legend(['Decission taken','Decission proved right']);

# %% [markdown]
# # What is the Maximum result of wining match i.e either bat or field or the match is tie?

# %%
# result_df= ipl_df.loc[(ipl_df['result'] == 'tie')&(ipl_df['result'] == 'runs')&(ipl_df['result'] == 'wickets')['id','winner','toss_decision']]

# %%
result_df=ipl_df.groupby('result')[['id']].count()
result_df = result_df.sort_values('id', ascending = True).reset_index()
result_df.rename(columns = {'id':'total'},inplace=True)

# %%
result_df
# Out:
#     result  total
# 0      tie     13
# 1     runs    364
# 2  wickets    435

# %%
labels = list(result_df.result)

# %%
plt.figure(figsize=(8,10))
plt.title('Winning results',fontsize=25,fontweight='bold')
plt.pie(result_df.total,labels = labels,autopct='%1.2f%%',textprops={'fontsize': 18},colors = ['red','darkolivegreen','teal']);

# %% [markdown]
# # *Which team has won ipl trophy most of times?*

# %%
final = ipl_df.groupby('season').tail(1)
final
# Out:
#           id          city       date player_of_match  \
# 57    336040        Mumbai 2008-06-01       YK Pathan
# 114   392239  Johannesburg 2009-05-24        A Kumble
# 174   419165        Mumbai 2010-04-25        SK Raina
# 247   501271       Chennai 2011-05-28         M Vijay
# 321   548381       Chennai 2012-05-27        MS Bisla
# 397   598073       Kolkata 2013-05-26      KA Pollard
# 457   734049     Bengaluru 2014-06-01       MK Pandey
# 516   829823       Kolkata 2015-05-24       RG Sharma
# 576   981019     Bengaluru 2016-05-29     BCJ Cutting
# 635  1082650     Hyderabad 2017-05-21       KH Pandya
# 695  1136620        Mumbai 2018-05-27       SR Watson
# 755  1181768     Hyderabad 2019-05-12       JJ Bumrah
# 815  1237181         Dubai 2020-11-10        TA Boult
#
#                                          venue                        team1  \
# 57                  Dr DY Patil Sports Academy          Chennai Super Kings
# ...

# %%
final.winner.unique()
# Out:
# array(['Rajasthan Royals', 'Sunrisers Hyderabad', 'Chennai Super Kings',
#        'Kolkata Knight Riders', 'Mumbai Indians'], dtype=object)

# %%
final_df=final['winner'].value_counts().reset_index()
final_df.rename(columns={'index':'team','winner':'total'},inplace = True)
final_df
# Out:
#                     team  total
# 0         Mumbai Indians      5
# 1    Chennai Super Kings      3
# 2  Kolkata Knight Riders      2
# 3    Sunrisers Hyderabad      2
# 4       Rajasthan Royals      1

# %%
plt.figure(figsize=(10,10))
plt.title("Season Winners",fontweight='bold',fontsize=35)
plt.xlabel('Teams',fontweight='bold',fontsize=30)
plt.ylabel('Total Seasons',fontweight='bold',fontsize=30)
plt.xticks(rotation='58')
plt.tick_params(labelsize=15)
plt.bar(final_df.team,final_df.total,color = ['blue','yellow','darkorange','purple','cornflowerblue']);

# %% [markdown]
# # *How many matches did each season had?*

# %%
total_matches_df = ipl_df.groupby('season')[['id']].count()
tm = total_matches_df.sort_values('season',ascending = False).reset_index()
tm.rename(columns={ 'id':'matches' ,'season':'years' },inplace = True)

# %%
tm
# Out:
#     years  matches
# 0    2020       60
# 1    2019       60
# 2    2018       60
# 3    2017       59
# 4    2016       60
# 5    2015       59
# 6    2014       60
# 7    2013       76
# 8    2012       74
# 9    2011       73
# 10   2010       60
# 11   2009       57
# 12   2008       58

# %%
plt.figure(figsize=(20,10))
plt.grid()
plt.title('Total matches in each season',fontsize = 20,fontweight = 'bold')
plt.xlabel('IPL Seasons',fontsize = 20,fontweight = 'bold')
plt.ylabel('Matches',fontsize = 20,fontweight = 'bold');
plt.tick_params(labelsize=20)
plt.plot(tm.years,tm.matches,'o-b')
plt.bar(tm.years,tm.matches,color = 'skyblue');
